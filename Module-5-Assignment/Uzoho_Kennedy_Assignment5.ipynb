# %% [markdown]
# # Module Five Assignment: Cartpole Problem

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 1.0, score: 15
# Scores: (min: 15, avg: 15, max: 15)
#
# Run: 2, exploration: 0.8778091417340573, score: 31
# Scores: (min: 15, avg: 23, max: 31)
#
# Run: 3, exploration: 0.8061065909263957, score: 18
# Scores: (min: 15, avg: 21.333333333333332, max: 31)
#
# Run: 4, exploration: 0.736559652908221, score: 19
# Scores: (min: 15, avg: 20.75, max: 31)
#
# Run: 5, exploration: 0.6900935609921609, score: 14
# Scores: (min: 14, avg: 19.4, max: 31)
#
# Run: 6, exploration: 0.6242658676435396, score: 21
# Scores: (min: 14, avg: 19.666666666666668, max: 31)
#
# Run: 7, exploration: 0.5732736268885887, score: 18
# Scores: (min: 14, avg: 19.428571428571427, max: 31)
#
# Run: 8, exploration: 0.547986285490042, score: 10
# Scores: (min: 10, avg: 18.25, max: 31)
#
# Run: 9, exploration: 0.5032248303978422, score: 18
# Scores: (min: 10, avg: 18.22222222222222, max: 31)
#
# Run: 10, exploration: 0.46912134373457726, score: 15
# Scores: (min: 10, avg: 17.9, max: 31)
#
# Run: 11, exploration: 0.446186062443672, score: 11
# Scores: (min: 10, avg: 17.272727272727273, max: 31)
#
# Run: 12, exploration: 0.43080185560799106, score: 8
# Scores: (min: 8, avg: 16.5, max: 31)
#
# Run: 13, exploration: 0.3976004408064698, score: 17
# Scores: (min: 8, avg: 16.53846153846154, max: 31)
#
# Run: 14, exploration: 0.3632974174544486, score: 19
# Scores: (min: 8, avg: 16.714285714285715, max: 31)
#
# Run: 15, exploration: 0.3438081748424137, score: 12
# Scores: (min: 8, avg: 16.4, max: 31)
#
# Run: 16, exploration: 0.326999438029567, score: 11
# Scores: (min: 8, avg: 16.0625, max: 31)
#
# Run: 17, exploration: 0.3157247089126454, score: 8
# Scores: (min: 8, avg: 15.588235294117647, max: 31)
#
# Run: 18, exploration: 0.3017979588795719, score: 10
# Scores: (min: 8, avg: 15.277777777777779, max: 31)
#
# Run: 19, exploration: 0.28704309604425327, score: 11
# Scores: (min: 8, avg: 15.052631578947368, max: 31)
#
# Run: 20, exploration: 0.2730095965279488, score: 11
# Scores: (min: 8, avg: 14.85, max: 31)
#
# Run: 21, exploration: 0.2609670281126685, score: 10
# Scores: (min: 8, avg: 14.619047619047619, max: 31)
#
# Run: 22, exploration: 0.24820838415550486, score: 11
# Scores: (min: 8, avg: 14.454545454545455, max: 31)
#
# Run: 23, exploration: 0.2384520680152932, score: 9
# Scores: (min: 8, avg: 14.217391304347826, max: 31)
#
# Run: 24, exploration: 0.2290792429684691, score: 9
# Scores: (min: 8, avg: 14, max: 31)
#
# Run: 25, exploration: 0.21570623976979014, score: 13
# Scores: (min: 8, avg: 13.96, max: 31)
#
# Run: 26, exploration: 0.20516038984972615, score: 11
# Scores: (min: 8, avg: 13.846153846153847, max: 31)
#
# Run: 27, exploration: 0.19611067854912728, score: 10
# Scores: (min: 8, avg: 13.703703703703704, max: 31)
#
# Run: 28, exploration: 0.18373897616330553, score: 14
# Scores: (min: 8, avg: 13.714285714285714, max: 31)
#
# Run: 29, exploration: 0.1756341724525918, score: 10
# Scores: (min: 8, avg: 13.586206896551724, max: 31)
#
# Run: 30, exploration: 0.16873052768933355, score: 9
# Scores: (min: 8, avg: 13.433333333333334, max: 31)
#
# Run: 31, exploration: 0.16209824418995536, score: 9
# Scores: (min: 8, avg: 13.290322580645162, max: 31)
#
# Run: 32, exploration: 0.1549480222912372, score: 10
# Scores: (min: 8, avg: 13.1875, max: 31)
#
# Run: 33, exploration: 0.1473726336968319, score: 11
# Scores: (min: 8, avg: 13.121212121212121, max: 31)
#
# Run: 34, exploration: 0.14157986400593744, score: 9
# Scores: (min: 8, avg: 13, max: 31)
#
# Run: 35, exploration: 0.1346580429260134, score: 11
# Scores: (min: 8, avg: 12.942857142857143, max: 31)
#
# Run: 36, exploration: 0.12807462877562611, score: 11
# Scores: (min: 8, avg: 12.88888888888889, max: 31)
#
# Run: 37, exploration: 0.12304040492325048, score: 9
# Scores: (min: 8, avg: 12.783783783783784, max: 31)
#
# Run: 38, exploration: 0.11820406108847166, score: 9
# Scores: (min: 8, avg: 12.68421052631579, max: 31)
#
# Run: 39, exploration: 0.11242507996344034, score: 11
# Scores: (min: 8, avg: 12.64102564102564, max: 31)
#
# Run: 40, exploration: 0.10746596228306791, score: 10
# Scores: (min: 8, avg: 12.575, max: 31)
#
# Run: 41, exploration: 0.1032418023864836, score: 9
# Scores: (min: 8, avg: 12.487804878048781, max: 31)
#
# Run: 42, exploration: 0.09918368135888474, score: 9
# Scores: (min: 8, avg: 12.404761904761905, max: 31)
#
# Run: 43, exploration: 0.09480864735409487, score: 10
# Scores: (min: 8, avg: 12.348837209302326, max: 31)
#
# Run: 44, exploration: 0.0906265979439563, score: 10
# Scores: (min: 8, avg: 12.295454545454545, max: 31)
#
# Run: 45, exploration: 0.08662902049662846, score: 10
# Scores: (min: 8, avg: 12.244444444444444, max: 31)
#
# Run: 46, exploration: 0.08364210790237678, score: 8
# Scores: (min: 8, avg: 12.152173913043478, max: 31)
#
# Run: 47, exploration: 0.08075818212241151, score: 8
# Scores: (min: 8, avg: 12.063829787234043, max: 31)
#
# Run: 48, exploration: 0.07680992513462537, score: 11
# Scores: (min: 8, avg: 12.041666666666666, max: 31)
#
# Run: 49, exploration: 0.07342180695061275, score: 10
# Scores: (min: 8, avg: 12, max: 31)
#
# Run: 50, exploration: 0.07018314008827135, score: 10
# Scores: (min: 8, avg: 11.96, max: 31)
#
# Run: 51, exploration: 0.06708733218678724, score: 10
# Scores: (min: 8, avg: 11.92156862745098, max: 31)
#
# Run: 52, exploration: 0.06412808167716157, score: 10
# Scores: (min: 8, avg: 11.884615384615385, max: 31)
#
# Run: 53, exploration: 0.061607401965086545, score: 9
# Scores: (min: 8, avg: 11.830188679245284, max: 31)
#
# Run: 54, exploration: 0.058595424120670696, score: 11
# Scores: (min: 8, avg: 11.814814814814815, max: 31)
#
# Run: 55, exploration: 0.05601075525639029, score: 10
# Scores: (min: 8, avg: 11.781818181818181, max: 31)
#
# Run: 56, exploration: 0.05380914294022049, score: 9
# Scores: (min: 8, avg: 11.732142857142858, max: 31)
#
# Run: 57, exploration: 0.05092252885731386, score: 12
# Scores: (min: 8, avg: 11.736842105263158, max: 31)
#
# Run: 58, exploration: 0.04867631463831842, score: 10
# Scores: (min: 8, avg: 11.706896551724139, max: 31)
#
# Run: 59, exploration: 0.046065053286412784, score: 12
# Scores: (min: 8, avg: 11.711864406779661, max: 31)
#
# Run: 60, exploration: 0.04425437624418858, score: 9
# Scores: (min: 8, avg: 11.666666666666666, max: 31)
#
# Run: 61, exploration: 0.04272851397543923, score: 8
# Scores: (min: 8, avg: 11.60655737704918, max: 31)
#
# Run: 62, exploration: 0.04125526245077418, score: 8
# Scores: (min: 8, avg: 11.548387096774194, max: 31)
#
# Run: 63, exploration: 0.03963364364733769, score: 9
# Scores: (min: 8, avg: 11.507936507936508, max: 31)
#
# Run: 64, exploration: 0.038075765743545126, score: 9
# Scores: (min: 8, avg: 11.46875, max: 31)
#
# Run: 65, exploration: 0.036396227662238566, score: 10
# Scores: (min: 8, avg: 11.446153846153846, max: 31)
#
# Run: 66, exploration: 0.03479077471386296, score: 10
# Scores: (min: 8, avg: 11.424242424242424, max: 31)
#
# Run: 67, exploration: 0.03325613897196732, score: 10
# Scores: (min: 8, avg: 11.402985074626866, max: 31)
#
# Run: 68, exploration: 0.03178919665971424, score: 10
# Scores: (min: 8, avg: 11.382352941176471, max: 31)
#
# Run: 69, exploration: 0.03038696179137978, score: 10
# Scores: (min: 8, avg: 11.36231884057971, max: 31)
#
# Run: 70, exploration: 0.02904658009432929, score: 10
# Scores: (min: 8, avg: 11.342857142857143, max: 31)
#
# Run: 71, exploration: 0.027765323199097504, score: 10
# Scores: (min: 8, avg: 11.32394366197183, max: 31)
#
# Run: 72, exploration: 0.02654058308574668, score: 10
# Scores: (min: 8, avg: 11.305555555555555, max: 31)
#
# Run: 73, exploration: 0.025497353542912736, score: 9
# Scores: (min: 8, avg: 11.273972602739725, max: 31)
#
# Run: 74, exploration: 0.02449513017825978, score: 9
# Scores: (min: 8, avg: 11.243243243243244, max: 31)
#
# Run: 75, exploration: 0.02260731802731653, score: 17
# Scores: (min: 8, avg: 11.32, max: 31)
#
# Run: 76, exploration: 0.02171869316274056, score: 9
# Scores: (min: 8, avg: 11.289473684210526, max: 31)
#
# Run: 77, exploration: 0.020450816818411825, score: 13
# Scores: (min: 8, avg: 11.311688311688311, max: 31)
#
# Run: 78, exploration: 0.019745685882295267, score: 8
# Scores: (min: 8, avg: 11.26923076923077, max: 31)
#
# Run: 79, exploration: 0.016651638319386028, score: 35
# Scores: (min: 8, avg: 11.569620253164556, max: 35)
#
# Run: 80, exploration: 0.014326806379480736, score: 31
# Scores: (min: 8, avg: 11.8125, max: 35)
#
# Run: 81, exploration: 0.013422995398979608, score: 14
# Scores: (min: 8, avg: 11.839506172839506, max: 35)
#
# Run: 82, exploration: 0.012388500230681249, score: 17
# Scores: (min: 8, avg: 11.902439024390244, max: 35)
#
# Run: 83, exploration: 0.01166529436067347, score: 13
# Scores: (min: 8, avg: 11.91566265060241, max: 35)
#
# Run: 84, exploration: 0.011039504743095268, score: 12
# Scores: (min: 8, avg: 11.916666666666666, max: 35)
#
# Run: 85, exploration: 0.010239902030817916, score: 16
# Scores: (min: 8, avg: 11.964705882352941, max: 35)
#
# Run: 86, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.034883720930232, max: 35)
#
# Run: 87, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 12.022988505747126, max: 35)
#
# Run: 88, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 12.147727272727273, max: 35)
#
# Run: 89, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 12.337078651685394, max: 35)
#
# Run: 90, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 12.511111111111111, max: 35)
#
# Run: 91, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 12.736263736263735, max: 35)
#
# Run: 92, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 12.793478260869565, max: 35)
#
# Run: 93, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 13.03225806451613, max: 35)
#
# Run: 94, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 13.159574468085106, max: 35)
#
# Run: 95, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 13.463157894736842, max: 42)
#
# Run: 96, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 13.677083333333334, max: 42)
#
# Run: 97, exploration: 0.01, score: 33
# Scores: (min: 8, avg: 13.876288659793815, max: 42)
#
# Run: 98, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 14.091836734693878, max: 42)
#
# Run: 99, exploration: 0.01, score: 64
# Scores: (min: 8, avg: 14.595959595959595, max: 64)
#
# Run: 100, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 14.83, max: 64)
#
# Run: 101, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 14.95, max: 64)
#
# Run: 102, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 15.07, max: 64)
#
# Run: 103, exploration: 0.01, score: 27
# Scores: (min: 8, avg: 15.16, max: 64)
#
# Run: 104, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 15.27, max: 64)
#
# Run: 105, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 15.44, max: 64)
#
# Run: 106, exploration: 0.01, score: 11
# Scores: (min: 8, avg: 15.34, max: 64)
#
# Run: 107, exploration: 0.01, score: 45
# Scores: (min: 8, avg: 15.61, max: 64)
#
# Run: 108, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 15.75, max: 64)
#
# Run: 109, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 15.97, max: 64)
#
# Run: 110, exploration: 0.01, score: 43
# Scores: (min: 8, avg: 16.25, max: 64)
#
# Run: 111, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 16.38, max: 64)
#
# Run: 112, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 16.78, max: 64)
#
# Run: 113, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 17.11, max: 64)
#
# Run: 114, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 17.26, max: 64)
#
# Run: 115, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 17.23, max: 64)
#
# Run: 116, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 17.38, max: 64)
#
# Run: 117, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 17.42, max: 64)
#
# Run: 118, exploration: 0.01, score: 16
# Scores: (min: 8, avg: 17.48, max: 64)
#
# Run: 119, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 17.61, max: 64)
#
# Run: 120, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 17.97, max: 64)
#
# Run: 121, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 18.48, max: 64)
#
# Run: 122, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 18.61, max: 64)
#
# Run: 123, exploration: 0.01, score: 88
# Scores: (min: 8, avg: 19.4, max: 88)
#
# Run: 124, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 19.71, max: 88)
#
# Run: 125, exploration: 0.01, score: 26
# Scores: (min: 8, avg: 19.84, max: 88)
#
# Run: 126, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 19.97, max: 88)
#
# Run: 127, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 20.34, max: 88)
#
# Run: 128, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 20.74, max: 88)
#
# Run: 129, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 20.87, max: 88)
#
# Run: 130, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 21.29, max: 88)
#
# Run: 131, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 21.49, max: 88)
#
# Run: 132, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 21.71, max: 88)
#
# Run: 133, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 21.82, max: 88)
#
# Run: 134, exploration: 0.01, score: 15
# Scores: (min: 8, avg: 21.88, max: 88)
#
# Run: 135, exploration: 0.01, score: 41
# Scores: (min: 8, avg: 22.18, max: 88)
#
# Run: 136, exploration: 0.01, score: 30
# Scores: (min: 8, avg: 22.37, max: 88)
#
# Run: 137, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 22.76, max: 88)
#
# Run: 138, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 23.14, max: 88)
#
# Run: 139, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 23.35, max: 88)
#
# Run: 140, exploration: 0.01, score: 24
# Scores: (min: 8, avg: 23.49, max: 88)
#
# Run: 141, exploration: 0.01, score: 28
# Scores: (min: 8, avg: 23.68, max: 88)
#
# Run: 142, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 23.84, max: 88)
#
# Run: 143, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 24.14, max: 88)
#
# Run: 144, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 24.57, max: 88)
#
# Run: 145, exploration: 0.01, score: 91
# Scores: (min: 8, avg: 25.38, max: 91)
#
# Run: 146, exploration: 0.01, score: 53
# Scores: (min: 8, avg: 25.83, max: 91)
#
# Run: 147, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 26.22, max: 91)
#
# Run: 148, exploration: 0.01, score: 106
# Scores: (min: 8, avg: 27.17, max: 106)
#
# Run: 149, exploration: 0.01, score: 75
# Scores: (min: 8, avg: 27.82, max: 106)
#
# Run: 150, exploration: 0.01, score: 119
# Scores: (min: 8, avg: 28.91, max: 119)
#
# Run: 151, exploration: 0.01, score: 122
# Scores: (min: 8, avg: 30.03, max: 122)
#
# Run: 152, exploration: 0.01, score: 294
# Scores: (min: 8, avg: 32.87, max: 294)
#
# Run: 153, exploration: 0.01, score: 198
# Scores: (min: 8, avg: 34.76, max: 294)
#
# Run: 154, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 36.39, max: 294)
#
# Run: 155, exploration: 0.01, score: 282
# Scores: (min: 8, avg: 39.11, max: 294)
#
# Run: 156, exploration: 0.01, score: 241
# Scores: (min: 8, avg: 41.43, max: 294)
#
# Run: 157, exploration: 0.01, score: 174
# Scores: (min: 8, avg: 43.05, max: 294)
#
# Run: 158, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 44.61, max: 294)
#
# Run: 159, exploration: 0.01, score: 217
# Scores: (min: 8, avg: 46.66, max: 294)
#
# Run: 160, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 48.17, max: 294)
#
# Run: 161, exploration: 0.01, score: 223
# Scores: (min: 8, avg: 50.32, max: 294)
#
# Run: 162, exploration: 0.01, score: 162
# Scores: (min: 8, avg: 51.86, max: 294)
#
# Run: 163, exploration: 0.01, score: 226
# Scores: (min: 8, avg: 54.03, max: 294)
#
# Run: 164, exploration: 0.01, score: 160
# Scores: (min: 8, avg: 55.54, max: 294)
#
# Run: 165, exploration: 0.01, score: 171
# Scores: (min: 8, avg: 57.15, max: 294)
#
# Run: 166, exploration: 0.01, score: 195
# Scores: (min: 8, avg: 59, max: 294)
#
# Run: 167, exploration: 0.01, score: 180
# Scores: (min: 8, avg: 60.7, max: 294)
#
# Run: 168, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 62.72, max: 294)
#
# Run: 169, exploration: 0.01, score: 250
# Scores: (min: 8, avg: 65.12, max: 294)
#
# Run: 170, exploration: 0.01, score: 284
# Scores: (min: 8, avg: 67.86, max: 294)
#
# Run: 171, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 69.94, max: 294)
#
# Run: 172, exploration: 0.01, score: 220
# Scores: (min: 8, avg: 72.04, max: 294)
#
# Run: 173, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 74.43, max: 294)
#
# Run: 174, exploration: 0.01, score: 190
# Scores: (min: 8, avg: 76.24, max: 294)
#
# Run: 175, exploration: 0.01, score: 220
# Scores: (min: 8, avg: 78.27, max: 294)
#
# Run: 176, exploration: 0.01, score: 207
# Scores: (min: 8, avg: 80.25, max: 294)
#
# Run: 177, exploration: 0.01, score: 221
# Scores: (min: 8, avg: 82.33, max: 294)
#
# Run: 178, exploration: 0.01, score: 360
# Scores: (min: 9, avg: 85.85, max: 360)
#
# Run: 179, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 87.74, max: 360)
#
# Run: 180, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 90.2, max: 360)
#
# Run: 181, exploration: 0.01, score: 227
# Scores: (min: 9, avg: 92.33, max: 360)
#
# Run: 182, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 94.44, max: 360)
#
# Run: 183, exploration: 0.01, score: 211
# Scores: (min: 9, avg: 96.42, max: 360)
#
# Run: 184, exploration: 0.01, score: 277
# Scores: (min: 9, avg: 99.07, max: 360)
#
# Run: 185, exploration: 0.01, score: 234
# Scores: (min: 9, avg: 101.25, max: 360)
#
# Run: 186, exploration: 0.01, score: 205
# Scores: (min: 9, avg: 103.12, max: 360)
#
# Run: 187, exploration: 0.01, score: 251
# Scores: (min: 9, avg: 105.52, max: 360)
#
# Run: 188, exploration: 0.01, score: 236
# Scores: (min: 9, avg: 107.65, max: 360)
#
# Run: 189, exploration: 0.01, score: 255
# Scores: (min: 9, avg: 109.91, max: 360)
#
# Run: 190, exploration: 0.01, score: 328
# Scores: (min: 9, avg: 112.91, max: 360)
#
# Run: 191, exploration: 0.01, score: 283
# Scores: (min: 9, avg: 115.41, max: 360)
#
# Run: 192, exploration: 0.01, score: 313
# Scores: (min: 9, avg: 118.36, max: 360)
#
# Run: 193, exploration: 0.01, score: 211
# Scores: (min: 9, avg: 120.12, max: 360)
#
# Run: 194, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 122.49, max: 360)
#
# Run: 195, exploration: 0.01, score: 237
# Scores: (min: 9, avg: 124.44, max: 360)
#
# Run: 196, exploration: 0.01, score: 320
# Scores: (min: 9, avg: 127.3, max: 360)
#
# Run: 197, exploration: 0.01, score: 359
# Scores: (min: 9, avg: 130.56, max: 360)
#
# Run: 198, exploration: 0.01, score: 362
# Scores: (min: 9, avg: 133.83, max: 362)
#
# Run: 199, exploration: 0.01, score: 249
# Scores: (min: 9, avg: 135.68, max: 362)
#
# Run: 200, exploration: 0.01, score: 415
# Scores: (min: 9, avg: 139.45, max: 415)
#
# Run: 201, exploration: 0.01, score: 258
# Scores: (min: 9, avg: 141.76, max: 415)
#
# Run: 202, exploration: 0.01, score: 262
# Scores: (min: 9, avg: 143.95, max: 415)
#
# Run: 203, exploration: 0.01, score: 212
# Scores: (min: 9, avg: 145.8, max: 415)
#
# Run: 204, exploration: 0.01, score: 215
# Scores: (min: 9, avg: 147.65, max: 415)
#
# Run: 205, exploration: 0.01, score: 378
# Scores: (min: 9, avg: 151.12, max: 415)
#
# Run: 206, exploration: 0.01, score: 281
# Scores: (min: 9, avg: 153.82, max: 415)
#
# Run: 207, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 155.89, max: 415)
#
# Run: 208, exploration: 0.01, score: 252
# Scores: (min: 9, avg: 158.17, max: 415)
#
# Run: 209, exploration: 0.01, score: 347
# Scores: (min: 9, avg: 161.24, max: 415)
#
# Run: 210, exploration: 0.01, score: 241
# Scores: (min: 9, avg: 163.22, max: 415)
#
# Run: 211, exploration: 0.01, score: 327
# Scores: (min: 9, avg: 166.25, max: 415)
#
# Run: 212, exploration: 0.01, score: 242
# Scores: (min: 9, avg: 168.19, max: 415)
#
# Run: 213, exploration: 0.01, score: 278
# Scores: (min: 9, avg: 170.47, max: 415)
#
# Run: 214, exploration: 0.01, score: 242
# Scores: (min: 9, avg: 172.55, max: 415)
#
# Run: 215, exploration: 0.01, score: 272
# Scores: (min: 12, avg: 175.18, max: 415)
#
# Run: 216, exploration: 0.01, score: 367
# Scores: (min: 12, avg: 178.59, max: 415)
#
# Run: 217, exploration: 0.01, score: 319
# Scores: (min: 15, avg: 181.66, max: 415)
#
# Run: 218, exploration: 0.01, score: 295
# Scores: (min: 15, avg: 184.45, max: 415)
#
# Run: 219, exploration: 0.01, score: 260
# Scores: (min: 15, avg: 186.81, max: 415)
#
# Run: 220, exploration: 0.01, score: 331
# Scores: (min: 15, avg: 189.65, max: 415)
#
# Run: 221, exploration: 0.01, score: 500
# Scores: (min: 15, avg: 194.04, max: 500)
#
# Run: 222, exploration: 0.01, score: 427
# Scores: (min: 15, avg: 198.07, max: 500)
#
# Solved in 122 runs, 222 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-bea6327a4fd8> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# Note: If the code is running properly, you should begin to see output appearing above this code block. It will take several minutes, so it is recommended that you let this code run in the background while completing other work. When the code has finished, it will print output saying, "Solved in _ runs, _ total runs."
#
# You may see an error about not having an exit command. This error does not affect the program's functionality and results from the steps taken to convert the code from Python 2.x to Python 3. Please disregard this error.

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.95  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 0.5  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()
# Out:
# Using TensorFlow backend.

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.5, score: 14
# Scores: (min: 14, avg: 14, max: 14)
#
# Run: 2, exploration: 0.47081140345718786, score: 18
# Scores: (min: 14, avg: 16, max: 18)
#
# Run: 3, exploration: 0.4523052401373088, score: 9
# Scores: (min: 9, avg: 13.666666666666666, max: 18)
#
# Run: 4, exploration: 0.389156278534321, score: 31
# Scores: (min: 9, avg: 18, max: 31)
#
# Run: 5, exploration: 0.2753699927085638, score: 70
# Scores: (min: 9, avg: 28.4, max: 70)
#
# Run: 6, exploration: 0.1807404651835882, score: 85
# Scores: (min: 9, avg: 37.833333333333336, max: 85)
#
# Run: 7, exploration: 0.14352154802212663, score: 47
# Scores: (min: 9, avg: 39.142857142857146, max: 85)
#
# Run: 8, exploration: 0.1192260340076466, score: 38
# Scores: (min: 9, avg: 39, max: 85)
#
# Run: 9, exploration: 0.05136279668727559, score: 169
# Scores: (min: 9, avg: 53.44444444444444, max: 169)
#
# Run: 10, exploration: 0.024955845615029167, score: 145
# Scores: (min: 9, avg: 62.6, max: 169)
#
# Run: 11, exploration: 0.01884797999012663, score: 57
# Scores: (min: 9, avg: 62.09090909090909, max: 169)
#
# Run: 12, exploration: 0.017308410420146823, score: 18
# Scores: (min: 9, avg: 58.416666666666664, max: 169)
#
# Run: 13, exploration: 0.010276792371061218, score: 105
# Scores: (min: 9, avg: 62, max: 169)
#
# Run: 14, exploration: 0.01, score: 136
# Scores: (min: 9, avg: 67.28571428571429, max: 169)
#
# Run: 15, exploration: 0.01, score: 307
# Scores: (min: 9, avg: 83.26666666666667, max: 307)
#
# Run: 16, exploration: 0.01, score: 321
# Scores: (min: 9, avg: 98.125, max: 321)
#
# Run: 17, exploration: 0.01, score: 297
# Scores: (min: 9, avg: 109.82352941176471, max: 321)
#
# Run: 18, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 131.5, max: 500)
#
# Run: 19, exploration: 0.01, score: 457
# Scores: (min: 9, avg: 148.6315789473684, max: 500)
#
# Run: 20, exploration: 0.01, score: 422
# Scores: (min: 9, avg: 162.3, max: 500)
#
# Run: 21, exploration: 0.01, score: 246
# Scores: (min: 9, avg: 166.28571428571428, max: 500)
#
# Run: 22, exploration: 0.01, score: 281
# Scores: (min: 9, avg: 171.5, max: 500)
#
# Run: 23, exploration: 0.01, score: 317
# Scores: (min: 9, avg: 177.82608695652175, max: 500)
#
# Run: 24, exploration: 0.01, score: 462
# Scores: (min: 9, avg: 189.66666666666666, max: 500)
#
# Run: 25, exploration: 0.01, score: 238
# Scores: (min: 9, avg: 191.6, max: 500)
#
# Run: 26, exploration: 0.01, score: 311
# Scores: (min: 9, avg: 196.19230769230768, max: 500)
#
# Run: 27, exploration: 0.01, score: 224
# Scores: (min: 9, avg: 197.22222222222223, max: 500)
#
# Run: 28, exploration: 0.01, score: 238
# Scores: (min: 9, avg: 198.67857142857142, max: 500)
#
# Run: 29, exploration: 0.01, score: 302
# Scores: (min: 9, avg: 202.24137931034483, max: 500)
#
# Run: 30, exploration: 0.01, score: 345
# Scores: (min: 9, avg: 207, max: 500)
#
# Run: 31, exploration: 0.01, score: 375
# Scores: (min: 9, avg: 212.41935483870967, max: 500)
#
# Run: 32, exploration: 0.01, score: 14
# Scores: (min: 9, avg: 206.21875, max: 500)
#
# Run: 33, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 215.12121212121212, max: 500)
#
# Run: 34, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 223.5, max: 500)
#
# Run: 35, exploration: 0.01, score: 362
# Scores: (min: 9, avg: 227.45714285714286, max: 500)
#
# Run: 36, exploration: 0.01, score: 126
# Scores: (min: 9, avg: 224.63888888888889, max: 500)
#
# Run: 37, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 232.0810810810811, max: 500)
#
# Run: 38, exploration: 0.01, score: 175
# Scores: (min: 9, avg: 230.57894736842104, max: 500)
#
# Run: 39, exploration: 0.01, score: 241
# Scores: (min: 9, avg: 230.84615384615384, max: 500)
#
# Run: 40, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 227.75, max: 500)
#
# Run: 41, exploration: 0.01, score: 16
# Scores: (min: 9, avg: 222.58536585365854, max: 500)
#
# Run: 42, exploration: 0.01, score: 12
# Scores: (min: 9, avg: 217.57142857142858, max: 500)
#
# Run: 43, exploration: 0.01, score: 11
# Scores: (min: 9, avg: 212.7674418604651, max: 500)
#
# Run: 44, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 208.22727272727272, max: 500)
#
# Run: 45, exploration: 0.01, score: 217
# Scores: (min: 9, avg: 208.42222222222222, max: 500)
#
# Run: 46, exploration: 0.01, score: 171
# Scores: (min: 9, avg: 207.6086956521739, max: 500)
#
# Run: 47, exploration: 0.01, score: 107
# Scores: (min: 9, avg: 205.46808510638297, max: 500)
#
# Run: 48, exploration: 0.01, score: 359
# Scores: (min: 9, avg: 208.66666666666666, max: 500)
#
# Run: 49, exploration: 0.01, score: 397
# Scores: (min: 9, avg: 212.51020408163265, max: 500)
#
# Run: 50, exploration: 0.01, score: 130
# Scores: (min: 9, avg: 210.86, max: 500)
#
# Run: 51, exploration: 0.01, score: 362
# Scores: (min: 9, avg: 213.8235294117647, max: 500)
#
# Run: 52, exploration: 0.01, score: 206
# Scores: (min: 9, avg: 213.67307692307693, max: 500)
#
# Run: 53, exploration: 0.01, score: 141
# Scores: (min: 9, avg: 212.30188679245282, max: 500)
#
# Run: 54, exploration: 0.01, score: 13
# Scores: (min: 9, avg: 208.61111111111111, max: 500)
#
# Run: 55, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 205, max: 500)
#
# Run: 56, exploration: 0.01, score: 10
# Scores: (min: 9, avg: 201.51785714285714, max: 500)
#
# Run: 57, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 198.140350877193, max: 500)
#
# Run: 58, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 194.8793103448276, max: 500)
#
# Run: 59, exploration: 0.01, score: 9
# Scores: (min: 9, avg: 191.72881355932202, max: 500)
#
# Run: 60, exploration: 0.01, score: 8
# Scores: (min: 8, avg: 188.66666666666666, max: 500)
#
# Run: 61, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 185.7377049180328, max: 500)
#
# Run: 62, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 182.88709677419354, max: 500)
#
# Run: 63, exploration: 0.01, score: 10
# Scores: (min: 8, avg: 180.14285714285714, max: 500)
#
# Run: 64, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 177.515625, max: 500)
#
# Run: 65, exploration: 0.01, score: 359
# Scores: (min: 8, avg: 180.30769230769232, max: 500)
#
# Run: 66, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 185.15151515151516, max: 500)
#
# Run: 67, exploration: 0.01, score: 316
# Scores: (min: 8, avg: 187.1044776119403, max: 500)
#
# Run: 68, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 188.08823529411765, max: 500)
#
# Run: 69, exploration: 0.01, score: 212
# Scores: (min: 8, avg: 188.43478260869566, max: 500)
#
# Run: 70, exploration: 0.01, score: 170
# Scores: (min: 8, avg: 188.17142857142858, max: 500)
#
# Run: 71, exploration: 0.01, score: 165
# Scores: (min: 8, avg: 187.8450704225352, max: 500)
#
# Run: 72, exploration: 0.01, score: 194
# Scores: (min: 8, avg: 187.93055555555554, max: 500)
#
# Run: 73, exploration: 0.01, score: 168
# Scores: (min: 8, avg: 187.65753424657535, max: 500)
#
# Run: 74, exploration: 0.01, score: 420
# Scores: (min: 8, avg: 190.7972972972973, max: 500)
#
# Run: 75, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 188.89333333333335, max: 500)
#
# Run: 76, exploration: 0.01, score: 158
# Scores: (min: 8, avg: 188.48684210526315, max: 500)
#
# Run: 77, exploration: 0.01, score: 231
# Scores: (min: 8, avg: 189.03896103896105, max: 500)
#
# Run: 78, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 189.23076923076923, max: 500)
#
# Run: 79, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 193.16455696202533, max: 500)
#
# Run: 80, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 192.65, max: 500)
#
# Run: 81, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 193.40740740740742, max: 500)
#
# Run: 82, exploration: 0.01, score: 257
# Scores: (min: 8, avg: 194.1829268292683, max: 500)
#
# Run: 83, exploration: 0.01, score: 14
# Scores: (min: 8, avg: 192.0120481927711, max: 500)
#
# Run: 84, exploration: 0.01, score: 9
# Scores: (min: 8, avg: 189.83333333333334, max: 500)
#
# Run: 85, exploration: 0.01, score: 12
# Scores: (min: 8, avg: 187.74117647058824, max: 500)
#
# Run: 86, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 186.88372093023256, max: 500)
#
# Run: 87, exploration: 0.01, score: 80
# Scores: (min: 8, avg: 185.6551724137931, max: 500)
#
# Run: 88, exploration: 0.01, score: 18
# Scores: (min: 8, avg: 183.75, max: 500)
#
# Run: 89, exploration: 0.01, score: 100
# Scores: (min: 8, avg: 182.80898876404495, max: 500)
#
# Run: 90, exploration: 0.01, score: 185
# Scores: (min: 8, avg: 182.83333333333334, max: 500)
#
# Run: 91, exploration: 0.01, score: 167
# Scores: (min: 8, avg: 182.65934065934067, max: 500)
#
# Run: 92, exploration: 0.01, score: 151
# Scores: (min: 8, avg: 182.31521739130434, max: 500)
#
# Run: 93, exploration: 0.01, score: 310
# Scores: (min: 8, avg: 183.68817204301075, max: 500)
#
# Run: 94, exploration: 0.01, score: 152
# Scores: (min: 8, avg: 183.35106382978722, max: 500)
#
# Run: 95, exploration: 0.01, score: 147
# Scores: (min: 8, avg: 182.96842105263158, max: 500)
#
# Run: 96, exploration: 0.01, score: 280
# Scores: (min: 8, avg: 183.97916666666666, max: 500)
#
# Run: 97, exploration: 0.01, score: 204
# Scores: (min: 8, avg: 184.18556701030928, max: 500)
#
# Run: 98, exploration: 0.01, score: 233
# Scores: (min: 8, avg: 184.68367346938774, max: 500)
#
# Run: 99, exploration: 0.01, score: 485
# Scores: (min: 8, avg: 187.7171717171717, max: 500)
#
# Run: 100, exploration: 0.01, score: 133
# Scores: (min: 8, avg: 187.17, max: 500)
#
# Run: 101, exploration: 0.01, score: 362
# Scores: (min: 8, avg: 190.65, max: 500)
#
# Run: 102, exploration: 0.01, score: 131
# Scores: (min: 8, avg: 191.78, max: 500)
#
# Run: 103, exploration: 0.01, score: 179
# Scores: (min: 8, avg: 193.48, max: 500)
#
# Run: 104, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 195.23, max: 500)
#
# Solved in 4 runs, 104 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-1-07b8deaa0432> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %%
import random  
import gym  
import numpy as np  
from collections import deque  
from keras.models import Sequential  
from keras.layers import Dense  
from keras.optimizers import Adam  
  
  
from scores.score_logger import ScoreLogger  
  
ENV_NAME = "CartPole-v1"  
  
GAMMA = 0.99  
LEARNING_RATE = 0.001  
  
MEMORY_SIZE = 1000000  
BATCH_SIZE = 20  
  
EXPLORATION_MAX = 1.0  
EXPLORATION_MIN = 0.01  
EXPLORATION_DECAY = 0.995  
  
  
class DQNSolver:  
  
    def __init__(self, observation_space, action_space):  
        self.exploration_rate = EXPLORATION_MAX  
  
        self.action_space = action_space  
        self.memory = deque(maxlen=MEMORY_SIZE)  
  
        self.model = Sequential()  
        self.model.add(Dense(24, input_shape=(observation_space,), activation="relu"))  
        self.model.add(Dense(24, activation="relu"))  
        self.model.add(Dense(self.action_space, activation="linear"))  
        self.model.compile(loss="mse", optimizer=Adam(lr=LEARNING_RATE))  
  
    def remember(self, state, action, reward, next_state, done):  
        self.memory.append((state, action, reward, next_state, done))  
  
    def act(self, state):  
        if np.random.rand() < self.exploration_rate:  
            return random.randrange(self.action_space)  
        q_values = self.model.predict(state)  
        return np.argmax(q_values[0])  
  
    def experience_replay(self):  
        if len(self.memory) < BATCH_SIZE:  
            return  
        batch = random.sample(self.memory, BATCH_SIZE)  
        for state, action, reward, state_next, terminal in batch:  
            q_update = reward  
            if not terminal:  
                q_update = (reward + GAMMA * np.amax(self.model.predict(state_next)[0]))  
            q_values = self.model.predict(state)  
            q_values[0][action] = q_update  
            self.model.fit(state, q_values, verbose=0)  
        self.exploration_rate *= EXPLORATION_DECAY  
        self.exploration_rate = max(EXPLORATION_MIN, self.exploration_rate)  
  
  
def cartpole():  
    env = gym.make(ENV_NAME)  
    score_logger = ScoreLogger(ENV_NAME)  
    observation_space = env.observation_space.shape[0]  
    action_space = env.action_space.n  
    dqn_solver = DQNSolver(observation_space, action_space)  
    run = 0  
    while True:  
        run += 1  
        state = env.reset()  
        state = np.reshape(state, [1, observation_space])  
        step = 0  
        while True:  
            step += 1  
            #env.render()  
            action = dqn_solver.act(state)  
            state_next, reward, terminal, info = env.step(action)  
            reward = reward if not terminal else -reward  
            state_next = np.reshape(state_next, [1, observation_space])  
            dqn_solver.remember(state, action, reward, state_next, terminal)  
            state = state_next  
            if terminal:  
                print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))  
                score_logger.add_score(step, run)  
                break  
            dqn_solver.experience_replay()

# %%
cartpole()
# Out:
# Run: 1, exploration: 0.8911090557802088, score: 43
# Scores: (min: 43, avg: 43, max: 43)
#
# Run: 2, exploration: 0.8142285204175609, score: 19
# Scores: (min: 19, avg: 31, max: 43)
#
# Run: 3, exploration: 0.7514768435208588, score: 17
# Scores: (min: 17, avg: 26.333333333333332, max: 43)
#
# Run: 4, exploration: 0.6763948591909945, score: 22
# Scores: (min: 17, avg: 25.25, max: 43)
#
# Run: 5, exploration: 0.6180388156137953, score: 19
# Scores: (min: 17, avg: 24, max: 43)
#
# Run: 6, exploration: 0.5937455908197752, score: 9
# Scores: (min: 9, avg: 21.5, max: 43)
#
# Run: 7, exploration: 0.5618938591163328, score: 12
# Scores: (min: 9, avg: 20.142857142857142, max: 43)
#
# Run: 8, exploration: 0.5057535983897912, score: 22
# Scores: (min: 9, avg: 20.375, max: 43)
#
# Run: 9, exploration: 0.46211964903917074, score: 19
# Scores: (min: 9, avg: 20.22222222222222, max: 43)
#
# Run: 10, exploration: 0.40769130904675194, score: 26
# Scores: (min: 9, avg: 20.8, max: 43)
#
# Run: 11, exploration: 0.3858205374665315, score: 12
# Scores: (min: 9, avg: 20, max: 43)
#
# Run: 12, exploration: 0.3706551064126331, score: 9
# Scores: (min: 9, avg: 19.083333333333332, max: 43)
#
# Run: 13, exploration: 0.3507711574848344, score: 12
# Scores: (min: 9, avg: 18.53846153846154, max: 43)
#
# Run: 14, exploration: 0.33195389135223546, score: 12
# Scores: (min: 9, avg: 18.071428571428573, max: 43)
#
# Run: 15, exploration: 0.3173112652388396, score: 10
# Scores: (min: 9, avg: 17.533333333333335, max: 43)
#
# Run: 16, exploration: 0.3033145315372582, score: 10
# Scores: (min: 9, avg: 17.0625, max: 43)
#
# Run: 17, exploration: 0.28704309604425327, score: 12
# Scores: (min: 9, avg: 16.764705882352942, max: 43)
#
# Run: 18, exploration: 0.2662522686041882, score: 16
# Scores: (min: 9, avg: 16.72222222222222, max: 43)
#
# Run: 19, exploration: 0.24820838415550486, score: 15
# Scores: (min: 9, avg: 16.63157894736842, max: 43)
#
# Run: 20, exploration: 0.23725980767521673, score: 10
# Scores: (min: 9, avg: 16.3, max: 43)
#
# Run: 21, exploration: 0.22453190559909803, score: 12
# Scores: (min: 9, avg: 16.095238095238095, max: 43)
#
# Run: 22, exploration: 0.21462770857094118, score: 10
# Scores: (min: 9, avg: 15.818181818181818, max: 43)
#
# Run: 23, exploration: 0.2041345879004775, score: 11
# Scores: (min: 9, avg: 15.608695652173912, max: 43)
#
# Run: 24, exploration: 0.19415447453059972, score: 11
# Scores: (min: 9, avg: 15.416666666666666, max: 43)
#
# Run: 25, exploration: 0.18373897616330553, score: 12
# Scores: (min: 9, avg: 15.28, max: 43)
#
# Run: 26, exploration: 0.17475600159032884, score: 11
# Scores: (min: 9, avg: 15.115384615384615, max: 43)
#
# Run: 27, exploration: 0.1678868750508869, score: 9
# Scores: (min: 9, avg: 14.88888888888889, max: 43)
#
# Run: 28, exploration: 0.16048131420416054, score: 10
# Scores: (min: 9, avg: 14.714285714285714, max: 43)
#
# Run: 29, exploration: 0.1549480222912372, score: 8
# Scores: (min: 8, avg: 14.482758620689655, max: 43)
#
# Run: 30, exploration: 0.14811319969530845, score: 10
# Scores: (min: 8, avg: 14.333333333333334, max: 43)
#
# Run: 31, exploration: 0.14157986400593744, score: 10
# Scores: (min: 8, avg: 14.193548387096774, max: 43)
#
# Run: 32, exploration: 0.13601479046086049, score: 9
# Scores: (min: 8, avg: 14.03125, max: 43)
#
# Run: 33, exploration: 0.13066846301911936, score: 9
# Scores: (min: 8, avg: 13.878787878787879, max: 43)
#
# Run: 34, exploration: 0.1242800989098765, score: 11
# Scores: (min: 8, avg: 13.794117647058824, max: 43)
#
# Run: 35, exploration: 0.11939502647758558, score: 9
# Scores: (min: 8, avg: 13.657142857142857, max: 43)
#
# Run: 36, exploration: 0.11299003011401039, score: 12
# Scores: (min: 8, avg: 13.61111111111111, max: 43)
#
# Run: 37, exploration: 0.1063939893092943, score: 13
# Scores: (min: 8, avg: 13.594594594594595, max: 43)
#
# Run: 38, exploration: 0.09576389217857617, score: 22
# Scores: (min: 8, avg: 13.81578947368421, max: 43)
#
# Run: 39, exploration: 0.0888276147181114, score: 16
# Scores: (min: 8, avg: 13.871794871794872, max: 43)
#
# Run: 40, exploration: 0.07875931641927113, score: 25
# Scores: (min: 8, avg: 14.15, max: 43)
#
# Run: 41, exploration: 0.0716045256805401, score: 20
# Scores: (min: 8, avg: 14.292682926829269, max: 43)
#
# Run: 42, exploration: 0.06575561514114299, score: 18
# Scores: (min: 8, avg: 14.380952380952381, max: 43)
#
# Run: 43, exploration: 0.05918580250061433, score: 22
# Scores: (min: 8, avg: 14.55813953488372, max: 43)
#
# Run: 44, exploration: 0.05601075525639029, score: 12
# Scores: (min: 8, avg: 14.5, max: 43)
#
# Run: 45, exploration: 0.05066791621302729, score: 21
# Scores: (min: 8, avg: 14.644444444444444, max: 43)
#
# Run: 46, exploration: 0.04023414326483323, score: 47
# Scores: (min: 8, avg: 15.347826086956522, max: 47)
#
# Run: 47, exploration: 0.03657912327863173, score: 20
# Scores: (min: 8, avg: 15.446808510638299, max: 47)
#
# Run: 48, exploration: 0.027350922279685573, score: 59
# Scores: (min: 8, avg: 16.354166666666668, max: 59)
#
# Run: 49, exploration: 0.018132788524664028, score: 83
# Scores: (min: 8, avg: 17.714285714285715, max: 83)
#
# Run: 50, exploration: 0.013626370684745774, score: 58
# Scores: (min: 8, avg: 18.52, max: 83)
#
# Run: 51, exploration: 0.011606967888870102, score: 33
# Scores: (min: 8, avg: 18.80392156862745, max: 83)
#
# Run: 52, exploration: 0.010087070213020206, score: 29
# Scores: (min: 8, avg: 19, max: 83)
#
# Run: 53, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 19.18867924528302, max: 83)
#
# Run: 54, exploration: 0.01, score: 63
# Scores: (min: 8, avg: 20, max: 83)
#
# Run: 55, exploration: 0.01, score: 62
# Scores: (min: 8, avg: 20.763636363636362, max: 83)
#
# Run: 56, exploration: 0.01, score: 54
# Scores: (min: 8, avg: 21.357142857142858, max: 83)
#
# Run: 57, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 21.666666666666668, max: 83)
#
# Run: 58, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 22.155172413793103, max: 83)
#
# Run: 59, exploration: 0.01, score: 32
# Scores: (min: 8, avg: 22.322033898305083, max: 83)
#
# Run: 60, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 22.8, max: 83)
#
# Run: 61, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 23.24590163934426, max: 83)
#
# Run: 62, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 23.338709677419356, max: 83)
#
# Run: 63, exploration: 0.01, score: 31
# Scores: (min: 8, avg: 23.46031746031746, max: 83)
#
# Run: 64, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 24, max: 83)
#
# Run: 65, exploration: 0.01, score: 51
# Scores: (min: 8, avg: 24.415384615384614, max: 83)
#
# Run: 66, exploration: 0.01, score: 38
# Scores: (min: 8, avg: 24.62121212121212, max: 83)
#
# Run: 67, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 24.686567164179106, max: 83)
#
# Run: 68, exploration: 0.01, score: 97
# Scores: (min: 8, avg: 25.75, max: 97)
#
# Run: 69, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 25.956521739130434, max: 97)
#
# Run: 70, exploration: 0.01, score: 25
# Scores: (min: 8, avg: 25.942857142857143, max: 97)
#
# Run: 71, exploration: 0.01, score: 44
# Scores: (min: 8, avg: 26.197183098591548, max: 97)
#
# Run: 72, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 26.38888888888889, max: 97)
#
# Run: 73, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 26.34246575342466, max: 97)
#
# Run: 74, exploration: 0.01, score: 23
# Scores: (min: 8, avg: 26.2972972972973, max: 97)
#
# Run: 75, exploration: 0.01, score: 57
# Scores: (min: 8, avg: 26.706666666666667, max: 97)
#
# Run: 76, exploration: 0.01, score: 42
# Scores: (min: 8, avg: 26.907894736842106, max: 97)
#
# Run: 77, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 27, max: 97)
#
# Run: 78, exploration: 0.01, score: 29
# Scores: (min: 8, avg: 27.025641025641026, max: 97)
#
# Run: 79, exploration: 0.01, score: 35
# Scores: (min: 8, avg: 27.126582278481013, max: 97)
#
# Run: 80, exploration: 0.01, score: 22
# Scores: (min: 8, avg: 27.0625, max: 97)
#
# Run: 81, exploration: 0.01, score: 34
# Scores: (min: 8, avg: 27.14814814814815, max: 97)
#
# Run: 82, exploration: 0.01, score: 40
# Scores: (min: 8, avg: 27.304878048780488, max: 97)
#
# Run: 83, exploration: 0.01, score: 39
# Scores: (min: 8, avg: 27.44578313253012, max: 97)
#
# Run: 84, exploration: 0.01, score: 47
# Scores: (min: 8, avg: 27.678571428571427, max: 97)
#
# Run: 85, exploration: 0.01, score: 48
# Scores: (min: 8, avg: 27.91764705882353, max: 97)
#
# Run: 86, exploration: 0.01, score: 55
# Scores: (min: 8, avg: 28.232558139534884, max: 97)
#
# Run: 87, exploration: 0.01, score: 120
# Scores: (min: 8, avg: 29.28735632183908, max: 120)
#
# Run: 88, exploration: 0.01, score: 50
# Scores: (min: 8, avg: 29.522727272727273, max: 120)
#
# Run: 89, exploration: 0.01, score: 61
# Scores: (min: 8, avg: 29.876404494382022, max: 120)
#
# Run: 90, exploration: 0.01, score: 125
# Scores: (min: 8, avg: 30.933333333333334, max: 125)
#
# Run: 91, exploration: 0.01, score: 58
# Scores: (min: 8, avg: 31.23076923076923, max: 125)
#
# Run: 92, exploration: 0.01, score: 60
# Scores: (min: 8, avg: 31.543478260869566, max: 125)
#
# Run: 93, exploration: 0.01, score: 85
# Scores: (min: 8, avg: 32.11827956989247, max: 125)
#
# Run: 94, exploration: 0.01, score: 268
# Scores: (min: 8, avg: 34.62765957446808, max: 268)
#
# Run: 95, exploration: 0.01, score: 114
# Scores: (min: 8, avg: 35.463157894736845, max: 268)
#
# Run: 96, exploration: 0.01, score: 105
# Scores: (min: 8, avg: 36.1875, max: 268)
#
# Run: 97, exploration: 0.01, score: 116
# Scores: (min: 8, avg: 37.01030927835052, max: 268)
#
# Run: 98, exploration: 0.01, score: 112
# Scores: (min: 8, avg: 37.775510204081634, max: 268)
#
# Run: 99, exploration: 0.01, score: 104
# Scores: (min: 8, avg: 38.44444444444444, max: 268)
#
# Run: 100, exploration: 0.01, score: 197
# Scores: (min: 8, avg: 40.03, max: 268)
#
# Run: 101, exploration: 0.01, score: 166
# Scores: (min: 8, avg: 41.26, max: 268)
#
# Run: 102, exploration: 0.01, score: 177
# Scores: (min: 8, avg: 42.84, max: 268)
#
# Run: 103, exploration: 0.01, score: 175
# Scores: (min: 8, avg: 44.42, max: 268)
#
# Run: 104, exploration: 0.01, score: 291
# Scores: (min: 8, avg: 47.11, max: 291)
#
# Run: 105, exploration: 0.01, score: 183
# Scores: (min: 8, avg: 48.75, max: 291)
#
# Run: 106, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 50.84, max: 291)
#
# Run: 107, exploration: 0.01, score: 218
# Scores: (min: 8, avg: 52.9, max: 291)
#
# Run: 108, exploration: 0.01, score: 335
# Scores: (min: 8, avg: 56.03, max: 335)
#
# Run: 109, exploration: 0.01, score: 211
# Scores: (min: 8, avg: 57.95, max: 335)
#
# Run: 110, exploration: 0.01, score: 281
# Scores: (min: 8, avg: 60.5, max: 335)
#
# Run: 111, exploration: 0.01, score: 149
# Scores: (min: 8, avg: 61.87, max: 335)
#
# Run: 112, exploration: 0.01, score: 226
# Scores: (min: 8, avg: 64.04, max: 335)
#
# Run: 113, exploration: 0.01, score: 181
# Scores: (min: 8, avg: 65.73, max: 335)
#
# Run: 114, exploration: 0.01, score: 226
# Scores: (min: 8, avg: 67.87, max: 335)
#
# Run: 115, exploration: 0.01, score: 248
# Scores: (min: 8, avg: 70.25, max: 335)
#
# Run: 116, exploration: 0.01, score: 239
# Scores: (min: 8, avg: 72.54, max: 335)
#
# Run: 117, exploration: 0.01, score: 219
# Scores: (min: 8, avg: 74.61, max: 335)
#
# Run: 118, exploration: 0.01, score: 429
# Scores: (min: 8, avg: 78.74, max: 429)
#
# Run: 119, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 83.59, max: 500)
#
# Run: 120, exploration: 0.01, score: 96
# Scores: (min: 8, avg: 84.45, max: 500)
#
# Run: 121, exploration: 0.01, score: 199
# Scores: (min: 8, avg: 86.32, max: 500)
#
# Run: 122, exploration: 0.01, score: 344
# Scores: (min: 8, avg: 89.66, max: 500)
#
# Run: 123, exploration: 0.01, score: 245
# Scores: (min: 8, avg: 92, max: 500)
#
# Run: 124, exploration: 0.01, score: 255
# Scores: (min: 8, avg: 94.44, max: 500)
#
# Run: 125, exploration: 0.01, score: 206
# Scores: (min: 8, avg: 96.38, max: 500)
#
# Run: 126, exploration: 0.01, score: 265
# Scores: (min: 8, avg: 98.92, max: 500)
#
# Run: 127, exploration: 0.01, score: 254
# Scores: (min: 8, avg: 101.37, max: 500)
#
# Run: 128, exploration: 0.01, score: 500
# Scores: (min: 8, avg: 106.27, max: 500)
#
# Run: 129, exploration: 0.01, score: 223
# Scores: (min: 9, avg: 108.42, max: 500)
#
# Run: 130, exploration: 0.01, score: 228
# Scores: (min: 9, avg: 110.6, max: 500)
#
# Run: 131, exploration: 0.01, score: 500
# Scores: (min: 9, avg: 115.5, max: 500)
#
# Run: 132, exploration: 0.01, score: 306
# Scores: (min: 9, avg: 118.47, max: 500)
#
# Run: 133, exploration: 0.01, score: 424
# Scores: (min: 9, avg: 122.62, max: 500)
#
# Run: 134, exploration: 0.01, score: 405
# Scores: (min: 9, avg: 126.56, max: 500)
#
# Run: 135, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 131.47, max: 500)
#
# Run: 136, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 136.35, max: 500)
#
# Run: 137, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 141.22, max: 500)
#
# Run: 138, exploration: 0.01, score: 271
# Scores: (min: 12, avg: 143.71, max: 500)
#
# Run: 139, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 148.55, max: 500)
#
# Run: 140, exploration: 0.01, score: 365
# Scores: (min: 12, avg: 151.95, max: 500)
#
# Run: 141, exploration: 0.01, score: 477
# Scores: (min: 12, avg: 156.52, max: 500)
#
# Run: 142, exploration: 0.01, score: 352
# Scores: (min: 12, avg: 159.86, max: 500)
#
# Run: 143, exploration: 0.01, score: 500
# Scores: (min: 12, avg: 164.64, max: 500)
#
# Run: 144, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 169.52, max: 500)
#
# Run: 145, exploration: 0.01, score: 284
# Scores: (min: 20, avg: 172.15, max: 500)
#
# Run: 146, exploration: 0.01, score: 500
# Scores: (min: 20, avg: 176.68, max: 500)
#
# Run: 147, exploration: 0.01, score: 475
# Scores: (min: 22, avg: 181.23, max: 500)
#
# Run: 148, exploration: 0.01, score: 299
# Scores: (min: 22, avg: 183.63, max: 500)
#
# Run: 149, exploration: 0.01, score: 289
# Scores: (min: 22, avg: 185.69, max: 500)
#
# Run: 150, exploration: 0.01, score: 319
# Scores: (min: 22, avg: 188.3, max: 500)
#
# Run: 151, exploration: 0.01, score: 249
# Scores: (min: 22, avg: 190.46, max: 500)
#
# Run: 152, exploration: 0.01, score: 500
# Scores: (min: 22, avg: 195.17, max: 500)
#
# Solved in 52 runs, 152 total runs.
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-e23913c48dc8> in <module>
# ----> 1 cartpole()
#
# <ipython-input-3-dc1c13d87039> in cartpole()
#      84             if terminal:
#      85                 print ("Run: " + str(run) + ", exploration: " + str(dqn_solver.exploration_rate) + ", score: " + str(step))
# ---> 86                 score_logger.add_score(step, run)
#      87                 break
#      88             dqn_solver.experience_replay()
#
# U:\Cartpole\scores\score_logger.py in add_score(self, score, run)
#      52             #               show_trend=False,
#      53             #               show_legend=False)
# ---> 54             exit()
#      55
#      56     def _save_png(self, input_path, output_path, x_label, y_label, average_of_n_last, show_goal, show_trend, show_legend):
#
# NameError: name 'exit' is not defined

# %% [markdown]
# # Code Analysis
# ## Reinforcement learning experiments
#
# Each module used the same deep Q-learning algorithm to solve the cartpole problem. The main difference between the three experiments lies in the values of the exploration factor, discount factor, and learning rates.
#
# In the first experiment, the discount factor (GAMMA) is set to 0.95, the learning rate (LEARNING_RATE) is set to 0.001, the exploration factor (EXPLORATION_MAX) is set to 1.0, and the exploration decay (EXPLORATION_DECAY) is set to 0.995. The algorithm solved the problem in 122 runs out of 222 total runs.
#
# In the second experiment, the discount factor (GAMMA) and learning rate (LEARNING_RATE) remain the same, but the exploration factor (EXPLORATION_MAX) is decreased to 0.5. The algorithm solved the problem in 4 runs out of 104 total runs, which is a significant improvement compared to the first experiment.
#
# In the third experiment, the discount factor (GAMMA) is increased to 0.99, while the other parameters remain the same as the first experiment. The algorithm solved the problem in 52 runs out of 152 total runs.
#
# These results implies that changing the exploration factor has a significant impact on the performance of the algorithm, while the discount factor and learning rate play a less significant role in this particular problem. The main difference between the three experiments lies in the values of the exploration factor, discount factor, and learning rates.
#
#
# ## How reinforcement learning experiments
# The goal of the agent in this case is to balance the pole on top of the cart for as long as posible. The state values include the position and velocity of the cart and the angle velocity of the pole. These values are used as input to the neural network to make predictions about the best action to take. The posible actions that can be performed in the problem are either moving the acart to the left or to the right. The reinforcewment  algorithm used in the problem is Q-learning, a type of model-free reinforcement learning.
#
# ## How experience replay is applied to the cartpole problem.
# Experience replay is a technique used in reinforcement learning to store and reuse experiences to improve the stability and convergence of the learning process. In this cartpole problem, this means that after each episode, the agent will store the experiences it had (i.e., the state, action, reward, and next state) and use this data to update the Q-table. The discount factor is used to calculate short-term and long-term rewards in reinforcement learning. In the cartpole problem, the discount factor determines how much weight is given to future rewards compared to immediate rewards. Comparatively, a high discount factor will give more importance to future rewards, whereas a low discount factor will give more importance to immediate rewards.
#
# ## How neural networks are used in deep Q-learning.
# Neural networks are used in deep Q-learning to approximate the Q-table. The neural network takes in the state as input and outputs a prediction for each action.
# The neural network architecture used in cartpole problem is a simple feedforward neural network with two hidden layers.
# The neural network makes Q-learning algorithm more efficient by allowing for predictions about the best action to be made much more quickly compared to an explicit Q-table.
# The learning rate determines the rate at which the neural network updates its weights during training. Increasing the learning rate will make the neural network update its weights more quickly, whereas decreasing the learning rate will make the neural network update its weights more slowly. A high learning rate can result in instability, whereas a low learning rate can result in slow convergence.
#
# <h3 align="center">References</h3>
#  Brockman, G. (2020, September 1). OpenAI gym beta. OpenAI. Retrieved February 10, 2023, from https://openai.com/blog/openai-gym-beta/
#
#  Surma, G. (2018). Cartpole. Github repository. Retrieved from https://github.com/gsurma/cartpole.
